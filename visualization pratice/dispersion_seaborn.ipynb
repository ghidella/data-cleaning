# %%
# Importing libs
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt

# %%
# Importing dataset
df = pd.read_csv('datasets/co2.csv')
df.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
# Dispersion graphic using conc and uptake attributes, grouping by type
srn.scatterplot(x=df.conc, y=df.uptake, hue = df.Type)
# Out:
# <AxesSubplot:xlabel='conc', ylabel='uptake'>

# %%
# Selection of specific registers from database (Quebec and Mississippi)
q = df.loc[df['Type'] == 'Quebec']
m = df.loc[df['Type'] == 'Mississippi']

# %%
# Subgraphic (1 line and two columns) showing graphics about every region
plt.figure()
plt.subplot(1,2,1)
srn.scatterplot(x=q.conc,y=q.uptake).set_title('Quebec')
plt.subplot(1,2,2)
srn.scatterplot(x=m.conc,y=m.uptake).set_title('Mississippi')
plt.tight_layout()

# %%
# Refrigerated and not refrigerated
ch = df.loc[df['Treatment'] == 'chilled']
nc = df.loc[df['Treatment'] == 'nonchilled']

# %%
# Graphic with only 'chilled' and 'nonchilled'
plt.figure()
plt.subplot(1,2,1)
srn.scatterplot(x=ch.conc,y=ch.uptake).set_title('chilled')
plt.subplot(1,2,2)
srn.scatterplot(x=nc.conc,y=nc.uptake).set_title('nonchilled')
plt.tight_layout()

# %%
# Importing another dataset, esophageal cancer
df2 = pd.read_csv('datasets/esoph.csv')
df2
# Out:
#     agegp      alcgp     tobgp  ncases  ncontrols
# 0   25-34  0-39g/day  0-9g/day       0         40
# 1   25-34  0-39g/day     10-19       0         10
# 2   25-34  0-39g/day     20-29       0          6
# 3   25-34  0-39g/day       30+       0          5
# 4   25-34      40-79  0-9g/day       0         27
# ..    ...        ...       ...     ...        ...
# 83    75+      40-79       30+       1          1
# 84    75+     80-119  0-9g/day       1          1
# 85    75+     80-119     10-19       1          1
# 86    75+       120+  0-9g/day       2          2
# 87    75+       120+     10-19       1          1
#
# [88 rows x 5 columns]

# %%
# Graphic between the attributes 'alcgp' and 'ncontrols'
srn.catplot(x = 'alcgp', y = 'ncontrols', data = df2, jitter = False)

# %%
# Graphic between the attributes 'alcgp' and 'ncontrols', with groupment
srn.catplot(x = 'alcgp', y = 'ncontrols', data = df2, col = 'tobgp')
# adding col = 'tobgp', we will split the graphic in every possible case at the column tobgp
