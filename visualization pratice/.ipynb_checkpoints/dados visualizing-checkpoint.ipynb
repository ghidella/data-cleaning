# %%
# Importing libs
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as srn
import numpy as np

# %%
# Importing dataset
df = pd.read_csv('datasets/dados.csv')
df.shape
# Out:
# (187, 4)

# %%
# First elements
df.head()
# Out:
#    CODIGO               MUNICIPIO       PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1     113            SANTO ANGELO  16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3      13         CACAPAVA DO SUL  13674.54     485535.86
# 4     120             SAO GABRIEL  19912.38     533719.86

# %%
srn.histplot(df.PIB, kde=True, bins=10).set(title='PIB')
# Out:
# [Text(0.5, 1.0, 'PIB')]

# %%
# High density lower than 50000

# %%
srn.histplot(df.VALOREMPENHO, kde=True,bins=10).set(title='Empenho')
# Out:
# [Text(0.5, 1.0, 'Empenho')]

# %%
# High density lower than ~ 0.3

# %%
group = df.sort_values('PIB').head(10)
group = group.iloc[:,1:3]
group
# Out:
#                MUNICIPIO       PIB
# 88             REDENTORA   8236.63
# 11       AMARAL FERRADOR   9216.87
# 15   ENCRUZILHADA DO SUL  10372.80
# 66      SENTINELA DO SUL  10477.52
# 89    SAO VALERIO DO SUL  10503.72
# 6               PIRATINI  10811.67
# 56                  MATA  10935.82
# 37  SANTANA DA BOA VISTA  11172.34
# 16               CANGUCU  11213.34
# 47             JAQUIRANA  11413.37

# %%
group.plot.bar(x='MUNICIPIO', y='PIB', color = 'gray')
# Out:
# <AxesSubplot:xlabel='MUNICIPIO'>

# %%
group = df.sort_values('VALOREMPENHO').head(10)
group = group.iloc[:,[1,3]]
group
# Out:
#                    MUNICIPIO  VALOREMPENHO
# 186      GUARANI DAS MISSOES        172.13
# 184           GETULIO VARGAS        233.01
# 185          NOVA SANTA RITA        310.58
# 183     SANTA BARBARA DO SUL        365.00
# 182  SANTA VITORIA DO PALMAR        760.00
# 181              MATO LEITAO        760.00
# 180  SANTA VITORIA DO PALMAR        760.00
# 179              MATO LEITAO        760.00
# 178                 SAO SEPE       1186.00
# 177                     IJUI       5920.00

# %%
group.plot.bar(x='MUNICIPIO',y='VALOREMPENHO',color='gray')
# Out:
# <AxesSubplot:xlabel='MUNICIPIO'>
